# %%
# Descargamos el dataset
# !gdown --id 1u1MRRWnjoi3p5eWV6bOtJX4_bZ0DT4eu
# !unzip balanced_dataset.zip
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: balanced_dataset_default/data/idctjG4MjJwEA_video.jpg
#   inflating: balanced_dataset_default/data/idCTJkXenJkCk_video.jpg
#   inflating: balanced_dataset_default/data/idcTKbRC050UA_video.jpg
#   inflating: balanced_dataset_default/data/idctl16uxL9nY_video.jpg
#   inflating: balanced_dataset_default/data/idCTmEDYd2C1w_video.jpg
#   inflating: balanced_dataset_default/data/idcTN5X6bV1J8_video.jpg
#   inflating: balanced_dataset_default/data/idcu0CtwVMKaY_video.jpg
#   inflating: balanced_dataset_default/data/idcu0DPPhRSI0_video.jpg
#   inflating: balanced_dataset_default/data/idcU0DS2m-Glg_video.jpg
#   inflating: balanced_dataset_default/data/idcU0E7eDWYMw_video.jpg
#   inflating: balanced_dataset_default/data/idCU0eC-bR1RU_video.jpg
#   inflating: balanced_dataset_default/data/idCU0ehzT9Bbg_video.jpg
#   inflating: balanced_dataset_default/data/idCu0EN1CpWzU_video.jpg
#   inflating: balanced_dataset_default/data/idcu0feum1a5Y_video.jpg
#   inflating: balanced_dataset_default/data/idcU0F_LdnBFo_video.jpg
#   inflating: balanced_dataset_default/data/idcU0g-ugEjRY_video.jpg
#   inflating: balanced_dataset_default/data/idcu0gjhuftHM_video.jpg
#   inflating: balanced_dataset_default/data/idCu0GmgRmaC4_video.jpg
#   inflating: balanced_dataset_default/data/idCU0gS1RlENU_video.jpg
#   inflating: balanced_dataset_default/data/idCU0HcugyBvg_video.jpg
#   inflating: balanced_dataset_default/data/idCU0HonaYMkw_video.jpg
#   inflating: balanced_dataset_default/data/idcu0huEkf2bg_video.jpg
#   inflating: balanced_dataset_default/data/idcU0hvBkdslk_video.jpg
#   inflating: balanced_dataset_default/data/idCu0i2WGoqU8_video.jpg
#   inflating: balanced_dataset_default/data/idCU0I4AGNDQU_video.jpg
#   inflating: balanced_dataset_default/data/idcU0ihZ2kK_M_video.jpg
#   inflating: balanced_dataset_default/data/idCU0J8HZcPHM_video.jpg
#   inflating: balanced_dataset_default/data/idcU0JIhjzxRw_video.jpg
#   inflating: balanced_dataset_default/data/idcu0JKehphM0_video.jpg
#   inflating: balanced_dataset_default/data/idCU0jzN49LZQ_video.jpg
#   inflating: balanced_dataset_default/data/idcu0k0hRC70U_video.jpg
#   inflating: balanced_dataset_default/data/idcu0kCBngxKM_video.jpg
#   inflating: balanced_dataset_default/data/idCU0LMKM_07M_video.jpg
#   inflating: balanced_dataset_default/data/idcU0lSqOC1ZQ_video.jpg
#   inflating: balanced_dataset_default/data/idcu0M1-CVbZU_video.jpg
#   inflating: balanced_dataset_default/data/idCU0mibJlUZI_video.jpg
#   inflating: balanced_dataset_default/data/idcu0mKF1x7mI_video.jpg
#   inflating: balanced_dataset_default/data/idCU0MlF1LmEk_video.jpg
#   inflating: balanced_dataset_default/data/idcu0mSUxzSB0_video.jpg
#   inflating: balanced_dataset_default/data/idcU0MUZ91628_video.jpg
#   inflating: balanced_dataset_default/data/idCu0n0SP_lxU_video.jpg
#   inflating: balanced_dataset_default/data/idCU0N4PCAf68_video.jpg
#   inflating: balanced_dataset_default/data/idcU0O-YPR3PM_video.jpg
#   inflating: balanced_dataset_default/data/idcu0oaNK59vA_video.jpg
#   inflating: balanced_dataset_default/data/idCU0pbDMltZE_video.jpg
#   inflating: balanced_dataset_default/data/idcU0pLWAITnc_video.jpg
#   inflating: balanced_dataset_default/data/idcU0pMH3rWBk_video.jpg
#   inflating: balanced_dataset_default/data/idCu0Px_SzTKI_video.jpg
#   inflating: balanced_dataset_default/data/idCU0Q676upH4_video.jpg
#   inflating: balanced_dataset_default/data/idCu0Q7tQXluo_video.jpg
#   inflating: balanced_dataset_default/data/idcU0QiUarW9c_video.jpg
#   inflating: balanced_dataset_default/data/idCu0qrgZrnJE_video.jpg
#   inflating: balanced_dataset_default/data/idCu0qxMv4hqc_video.jpg
#   inflating: balanced_dataset_default/data/idCU0Qy0Gi1j8_video.jpg
#   inflating: balanced_dataset_default/data/idCU0R6mkKMY4_video.jpg
#   inflating: balanced_dataset_default/data/idcU0r8pq8ayc_video.jpg
#   inflating: balanced_dataset_default/data/idCU0RhH6qLt8_video.jpg
#   inflating: balanced_dataset_default/data/idcu0Srl5d_xM_video.jpg
#   inflating: balanced_dataset_default/data/idCu0TKQB4ECQ_video.jpg
#   inflating: balanced_dataset_default/data/idCU0TSiUfV1w_video.jpg
#   inflating: balanced_dataset_default/data/idCu0uN-drwgc_video.jpg
#   inflating: balanced_dataset_default/data/idCU0u_T27OKs_video.jpg
#   inflating: balanced_dataset_default/data/idcU0Vhs7kZ1c_video.jpg
#   inflating: balanced_dataset_default/data/idCu0VLvlHk0g_video.jpg
#   inflating: balanced_dataset_default/data/idcu0whF5T6rc_video.jpg
#   inflating: balanced_dataset_default/data/idCU0wOW_iXqE_video.jpg
#   inflating: balanced_dataset_default/data/idCU0WrGZf6Mk_video.jpg
#   inflating: balanced_dataset_default/data/idCu0WU5m1qes_video.jpg
#   inflating: balanced_dataset_default/data/idcu0x-TO5veo_video.jpg
#   inflating: balanced_dataset_default/data/idcu0XCGzbyM0_video.jpg
#   inflating: balanced_dataset_default/data/idCu0XFgxdMK4_video.jpg
#   inflating: balanced_dataset_default/data/idCu0Y7sQEO7U_video.jpg
#   inflating: balanced_dataset_default/data/idCu0yFvtV6cs_video.jpg
#   inflating: balanced_dataset_default/data/idCu0_iTq4KLE_video.jpg
#   inflating: balanced_dataset_default/data/idcU0_LiPQ-54_video.jpg
#   inflating: balanced_dataset_default/data/idcU12AHgjpSA_video.jpg
#   inflating: balanced_dataset_default/data/idCu14YQVozCY_video.jpg
#   inflating: balanced_dataset_default/data/idcU15Ti5k0yo_video.jpg
#   inflating: balanced_dataset_default/data/idcu19MYEYA28_video.jpg
#   inflating: balanced_dataset_default/data/idcu19Oc_hI7A_video.jpg
#   inflating: balanced_dataset_default/data/idcU1AS1dnJL4_video.jpg
#   inflating: balanced_dataset_default/data/idcU1bSqiwMTM_video.jpg
#   inflating: balanced_dataset_default/data/idCu1DOec3WZE_video.jpg
#   inflating: balanced_dataset_default/data/idCU1doLm4v4g_video.jpg
#   inflating: balanced_dataset_default/data/idcU1dWxKmL90_video.jpg
#   inflating: balanced_dataset_default/data/idCu1F96_MiYc_video.jpg
#   inflating: balanced_dataset_default/data/idCu1GC1jaYrg_video.jpg
#   inflating: balanced_dataset_default/data/idcU1gHbdc_qY_video.jpg
#   inflating: balanced_dataset_default/data/idCu1GXNjCX0Q_video.jpg
#   inflating: balanced_dataset_default/data/idcU1HO9dvDMM_video.jpg
#   inflating: balanced_dataset_default/data/idCu1k-6kAUao_video.jpg
#   inflating: balanced_dataset_default/data/idcU1kvF4VA8Y_video.jpg
#   inflating: balanced_dataset_default/data/idcU1kWVh4w_Y_video.jpg
#   inflating: balanced_dataset_default/data/idcU1myGYKavk_video.jpg
#   inflating: balanced_dataset_default/data/idCU1P8h99EpM_video.jpg
#   inflating: balanced_dataset_default/data/idCu1ppHsSLzQ_video.jpg
#   inflating: balanced_dataset_default/data/idCU1QBAu4-AM_video.jpg
#   inflating: balanced_dataset_default/data/idCu1sM6koBt4_video.jpg
#   inflating: balanced_dataset_default/data/idcU1U7nkUPv8_video.jpg
#   inflating: balanced_dataset_default/data/idCU1vUzFV1T0_video.jpg
#   inflating: balanced_dataset_default/data/idcU1WnxKvP78_video.jpg
#   inflating: balanced_dataset_default/data/idCu1zHg9uB94_video.jpg
#   inflating: balanced_dataset_default/data/idcU1ZU4cldIY_video.jpg
#   inflating: balanced_dataset_default/data/idcu24kGQoGuo_video.jpg
#   inflating: balanced_dataset_default/data/idcu275c8iGP8_video.jpg
#   inflating: balanced_dataset_default/data/idCu27N0xkGLM_video.jpg
#   inflating: balanced_dataset_default/data/idCu294sgmAx8_video.jpg
#   inflating: balanced_dataset_default/data/idCu2BSj8amOQ_video.jpg
#   inflating: balanced_dataset_default/data/idcu2eenG3tQM_video.jpg
#   inflating: balanced_dataset_default/data/idCu2fP6WQmBI_video.jpg
#   inflating: balanced_dataset_default/data/idCU2gCjB8QBQ_video.jpg
#   inflating: balanced_dataset_default/data/idcU2H4RCCCWo_video.jpg
#   inflating: balanced_dataset_default/data/idcu2hzdocsgc_video.jpg
#   inflating: balanced_dataset_default/data/idCu2meN40CFA_video.jpg
#   inflating: balanced_dataset_default/data/idCU2Q9gO3UfE_video.jpg
#   inflating: balanced_dataset_default/data/idcU2SE9Mhsko_video.jpg
#   inflating: balanced_dataset_default/data/idcu2t5h5aZbk_video.jpg
#   inflating: balanced_dataset_default/data/idcu2tgxCynXk_video.jpg
#   inflating: balanced_dataset_default/data/idcu2To2eJS4I_video.jpg
#   inflating: balanced_dataset_default/data/idcU2TR4JtCOI_video.jpg
#   inflating: balanced_dataset_default/data/idCu2zQlBYTC0_video.jpg
#   inflating: balanced_dataset_default/data/idcU363pSR6WI_video.jpg
#   inflating: balanced_dataset_default/data/idCu3DVdiB_tE_video.jpg
#   inflating: balanced_dataset_default/data/idcu3gnXVm8Jk_video.jpg
#   inflating: balanced_dataset_default/data/idcu3HgwbJYRU_video.jpg
#   inflating: balanced_dataset_default/data/idcU3k9kRGCYw_video.jpg
#   inflating: balanced_dataset_default/data/idcU4Bo_rF_R0_video.jpg
#   inflating: balanced_dataset_default/data/idCu4DwKlxoAk_video.jpg
#   inflating: balanced_dataset_default/data/idcu4fK3T31yc_video.jpg
#   inflating: balanced_dataset_default/data/idcu4R6pZoVpo_video.jpg
#   inflating: balanced_dataset_default/data/idCU4SmG9zKS4_video.jpg
#   inflating: balanced_dataset_default/data/idcU4ZA7sH4aw_video.jpg
#   inflating: balanced_dataset_default/data/idcU56Kh731Q0_video.jpg
#   inflating: balanced_dataset_default/data/idcu572iXKa5U_video.jpg
#   inflating: balanced_dataset_default/data/idCu5aYcro4W8_video.jpg
#   inflating: balanced_dataset_default/data/idcu5uxHNJDIQ_video.jpg
#   inflating: balanced_dataset_default/data/idcu5zof5Mumw_video.jpg
#   inflating: balanced_dataset_default/data/idcU6aAJWRQvU_video.jpg
#   inflating: balanced_dataset_default/data/idCu6C6EhXbnQ_video.jpg
#   inflating: balanced_dataset_default/data/idCu6F4aYJDBY_video.jpg
#   inflating: balanced_dataset_default/data/idcU6kYmE5Jh4_video.jpg
#   inflating: balanced_dataset_default/data/idCU6z-nk5xr4_video.jpg
#   inflating: balanced_dataset_default/data/idCu7-nRFJvi0_video.jpg
#   inflating: balanced_dataset_default/data/idCu7bBFnYfzA_video.jpg
#   inflating: balanced_dataset_default/data/idcu7CPEPTghE_video.jpg
#   inflating: balanced_dataset_default/data/idcU7xbxt4uKA_video.jpg
#   inflating: balanced_dataset_default/data/idCu7ZRKAIU_0_video.jpg
#   inflating: balanced_dataset_default/data/idCU8xQDos4zY_video.jpg
#   inflating: balanced_dataset_default/data/idcu90MZuSB_c_video.jpg
#   inflating: balanced_dataset_default/data/idcu93Bb62-Qs_video.jpg
#   inflating: balanced_dataset_default/data/idcu95D2mPFSU_video.jpg
#   inflating: balanced_dataset_default/data/idCu9aJtnA_u8_video.jpg
#   inflating: balanced_dataset_default/data/idcU9BysZpS2w_video.jpg
#   inflating: balanced_dataset_default/data/idcu9gdVrgKEE_video.jpg
#   inflating: balanced_dataset_default/data/idCu9hClbU-Ek_video.jpg
#   inflating: balanced_dataset_default/data/idCu9p5FGpr38_video.jpg
#   inflating: balanced_dataset_default/data/idCu9tKkuMHFE_video.jpg
#   inflating: balanced_dataset_default/data/idcUA3skXRtoY_video.jpg
#   inflating: balanced_dataset_default/data/idCuA4FrldjdU_video.jpg
#   inflating: balanced_dataset_default/data/idcua8VQ34U3A_video.jpg
#   inflating: balanced_dataset_default/data/idCUADS9qbzV4_video.jpg
#   inflating: balanced_dataset_default/data/idcuaEdwX_TIc_video.jpg
#   inflating: balanced_dataset_default/data/idcUaJMZDPtEg_video.jpg
#   inflating: balanced_dataset_default/data/idcUAt3YdT2dQ_video.jpg
#   inflating: balanced_dataset_default/data/idcuazxKdeCtU_video.jpg
#   inflating: balanced_dataset_default/data/idCUb--93ES4Y_video.jpg
#   inflating: balanced_dataset_default/data/idcuBTKzPPQ8M_video.jpg
#   inflating: balanced_dataset_default/data/idCuBV4JqnAFk_video.jpg
#   inflating: balanced_dataset_default/data/idcUctG1lngq8_video.jpg
#   inflating: balanced_dataset_default/data/idcUc_pcAj8So_video.jpg
#   inflating: balanced_dataset_default/data/idcUd5yfTwkOM_video.jpg
#   inflating: balanced_dataset_default/data/idcuDDPF6vE6Y_video.jpg
#   inflating: balanced_dataset_default/data/idCUeyg6yKM1A_video.jpg
#   inflating: balanced_dataset_default/data/idCuFj1CeFVCs_video.jpg
#   inflating: balanced_dataset_default/data/idCuGBpwnWW2I_video.jpg
#   inflating: balanced_dataset_default/data/idcUgReo37ECw_video.jpg
#   inflating: balanced_dataset_default/data/idCuh12dIVhEo_video.jpg
#   inflating: balanced_dataset_default/data/idCuhUZM62vjY_video.jpg
#   inflating: balanced_dataset_default/data/idcuiMEvpzvNA_video.jpg
#   inflating: balanced_dataset_default/data/idcUJ-gpRJyog_video.jpg
#   inflating: balanced_dataset_default/data/idCUjd98rZCVM_video.jpg
#   inflating: balanced_dataset_default/data/idcuJprLKMZtQ_video.jpg
#   inflating: balanced_dataset_default/data/idcuK6RDWBzAk_video.jpg
#   inflating: balanced_dataset_default/data/idcUKMNHjb_PQ_video.jpg
#   inflating: balanced_dataset_default/data/idcuKUVN6_du4_video.jpg
#   inflating: balanced_dataset_default/data/idcUli01Hzvwg_video.jpg
#   inflating: balanced_dataset_default/data/idCumZP6_9sHU_video.jpg
#   inflating: balanced_dataset_default/data/idCUNY2ENI9h4_video.jpg
#   inflating: balanced_dataset_default/data/idCUPoYSE9vxM_video.jpg
#   inflating: balanced_dataset_default/data/idcuPSSyF5UE0_video.jpg
#   inflating: balanced_dataset_default/data/idCuQ9ZyAk89k_video.jpg
#   inflating: balanced_dataset_default/data/idcUqUeWMd0jI_video.jpg
#   inflating: balanced_dataset_default/data/idcUqUqqzwgEM_video.jpg
#   inflating: balanced_dataset_default/data/idCurI7ZHv_V8_video.jpg
#   inflating: balanced_dataset_default/data/idCurO0SEdxq4_video.jpg
#   inflating: balanced_dataset_default/data/idCurZz4Hv_Bg_video.jpg
#   inflating: balanced_dataset_default/data/idcUT-TchhPr8_video.jpg
#   inflating: balanced_dataset_default/data/idCutizMeK5Bs_video.jpg
#   inflating: balanced_dataset_default/data/idcUTMi0xzQeM_video.jpg
#   inflating: balanced_dataset_default/data/idCUuEZ0v88n8_video.jpg
#   inflating: balanced_dataset_default/data/idCuunfAjpARY_video.jpg
#   inflating: balanced_dataset_default/data/idCuuYBK3B-0Q_video.jpg
#   inflating: balanced_dataset_default/data/idcuV5P9fCYjU_video.jpg
#   inflating: balanced_dataset_default/data/idCuV6bOzZlv8_video.jpg
#   inflating: balanced_dataset_default/data/idcuvMxg2oLdc_video.jpg
#   inflating: balanced_dataset_default/data/idcUVtA5Q4ao4_video.jpg
#   inflating: balanced_dataset_default/data/idcvOYu0fa3nA_video.jpg
#   inflating: balanced_dataset_default/data/idcVoYWlch6Uo_video.jpg
#   inflating: balanced_dataset_default/data/idCVoZb52ilfY_video.jpg
#   inflating: balanced_dataset_default/data/idCvOzduIxvb8_video.jpg
#   inflating: balanced_dataset_default/data/idcvOZIcQ06J4_video.jpg
#   inflating: balanced_dataset_default/data/idCvoZS3Is8Oo_video.jpg
#   inflating: balanced_dataset_default/data/idcVo_aN-Cts8_video.jpg
#   inflating: balanced_dataset_default/data/idcVO_sCNrTQQ_video.jpg
#   inflating: balanced_dataset_default/data/idCVO_xnFHnD8_video.jpg
#   inflating: balanced_dataset_default/data/idcVP-e433Mic_video.jpg
#   inflating: balanced_dataset_default/data/idcVP-eSXRJZs_video.jpg
#   inflating: balanced_dataset_default/data/idcVp-xuxtlCw_video.jpg
#   inflating: balanced_dataset_default/data/idCvP-y2RjIr0_video.jpg
#   inflating: balanced_dataset_default/data/idcVp-zw00-jw_video.jpg
#   inflating: balanced_dataset_default/data/idCvp0k8UHcq0_video.jpg
#   inflating: balanced_dataset_default/data/idcvP0odi4gNE_video.jpg
#   inflating: balanced_dataset_default/data/idcVP23zKRZ78_video.jpg
#   inflating: balanced_dataset_default/data/idCVP2H1o2J9g_video.jpg
#   inflating: balanced_dataset_default/data/idcVp35dzLCL0_video.jpg
#   inflating: balanced_dataset_default/data/idcvP3JEb62qQ_video.jpg
#   inflating: balanced_dataset_default/data/idcVP3mQsUWo0_video.jpg
#   inflating: balanced_dataset_default/data/idcVP3vQcoqmU_video.jpg
#   inflating: balanced_dataset_default/data/idCvp4ivF53o0_video.jpg
#   inflating: balanced_dataset_default/data/idcvp53P3SafY_video.jpg
#   inflating: balanced_dataset_default/data/idcVp5GNKzKWI_video.jpg
#   inflating: balanced_dataset_default/data/idcvP5n3QuLSU_video.jpg
#   inflating: balanced_dataset_default/data/idcVp6mrs806I_video.jpg
#   inflating: balanced_dataset_default/data/idcVp6mXtNnSc_video.jpg
#   inflating: balanced_dataset_default/data/idcvp6nXO9GYA_video.jpg
#   inflating: balanced_dataset_default/data/idcVP6R1Cbf6Q_video.jpg
#   inflating: balanced_dataset_default/data/idCVp6Verekbk_video.jpg
#   inflating: balanced_dataset_default/data/idCVP76rFvIqY_video.jpg
#   inflating: balanced_dataset_default/data/idcVP7AQAplac_video.jpg
#   inflating: balanced_dataset_default/data/idCvp7Aw-nv_o_video.jpg
#   inflating: balanced_dataset_default/data/idcvp7bbif5XE_video.jpg
#   inflating: balanced_dataset_default/data/idcvp83tovnJQ_video.jpg
#   inflating: balanced_dataset_default/data/idCVP8GJAgTSc_video.jpg
#   inflating: balanced_dataset_default/data/idcvp8sToWTgg_video.jpg
#   inflating: balanced_dataset_default/data/idcvp8vQ-STmY_video.jpg
#   inflating: balanced_dataset_default/data/idCVP9geuZ95M_video.jpg
#   inflating: balanced_dataset_default/data/idcVp9P1-fBy8_video.jpg
#   inflating: balanced_dataset_default/data/idCVP9zCh1LTA_video.jpg
#   inflating: balanced_dataset_default/data/idcVPAad6AvYA_video.jpg
#   inflating: balanced_dataset_default/data/idcvpABJITn28_video.jpg
#   inflating: balanced_dataset_default/data/idcVPaByZ0kGU_video.jpg
#   inflating: balanced_dataset_default/data/idCvpac7EuMs8_video.jpg
#   inflating: balanced_dataset_default/data/idCvpAq4oPPn0_video.jpg
#   inflating: balanced_dataset_default/data/idcVPaTUPx7LY_video.jpg
#   inflating: balanced_dataset_default/data/idcvpAw0pYmW8_video.jpg
#   inflating: balanced_dataset_default/data/idCvPAZOjk8Ak_video.jpg
#   inflating: balanced_dataset_default/data/idCvpB8E9mbRA_video.jpg
#   inflating: balanced_dataset_default/data/idCVPbgXWk_5c_video.jpg
#   inflating: balanced_dataset_default/data/idCVPbJ3bkHdA_video.jpg
#   inflating: balanced_dataset_default/data/idcVPbmlqUBx4_video.jpg
#   inflating: balanced_dataset_default/data/idcvPBoDlhWLE_video.jpg
#   inflating: balanced_dataset_default/data/idCvpbZ1Lbp0s_video.jpg
#   inflating: balanced_dataset_default/data/idCVPCcunDjtM_video.jpg
#   inflating: balanced_dataset_default/data/idCvPCE2ngvAM_video.jpg
#   inflating: balanced_dataset_default/data/idcVpcJVH6DIc_video.jpg
#   inflating: balanced_dataset_default/data/idCVPCvIVcjM8_video.jpg
#   inflating: balanced_dataset_default/data/idcvPCvtj3nyo_video.jpg
#   inflating: balanced_dataset_default/data/idCvPd4HYwpHs_video.jpg
#   inflating: balanced_dataset_default/data/idCVPDF2cykcI_video.jpg
#   inflating: balanced_dataset_default/data/idcvpD_Vs-8SQ_video.jpg
#   inflating: balanced_dataset_default/data/idcvpE-XlxNQQ_video.jpg
#   inflating: balanced_dataset_default/data/idcvPE0IFA1mA_video.jpg
#   inflating: balanced_dataset_default/data/idcVPe9K98IlU_video.jpg
#   inflating: balanced_dataset_default/data/idCvPeefXFsDQ_video.jpg
#   inflating: balanced_dataset_default/data/idCvpEJm9Xwow_video.jpg
#   inflating: balanced_dataset_default/data/idCvpeOH-GJHo_video.jpg
#   inflating: balanced_dataset_default/data/idcvpEO_EUCps_video.jpg
#   inflating: balanced_dataset_default/data/idCVPeWFCCIKw_video.jpg
#   inflating: balanced_dataset_default/data/idCvpfgjSjDLk_video.jpg
#   inflating: balanced_dataset_default/data/idcVpFWABaGiU_video.jpg
#   inflating: balanced_dataset_default/data/idcVPfwgDDmMY_video.jpg
#   inflating: balanced_dataset_default/data/idCvpgdRCfLGU_video.jpg
#   inflating: balanced_dataset_default/data/idcVpgtiSc4tc_video.jpg
#   inflating: balanced_dataset_default/data/idCVph_kBRZDY_video.jpg
#   inflating: balanced_dataset_default/data/idcVPI7jQ4-m4_video.jpg
#   inflating: balanced_dataset_default/data/idCVPJLm6v7SE_video.jpg
#   inflating: balanced_dataset_default/data/idcVPkStsw7Ak_video.jpg
#   inflating: balanced_dataset_default/data/idCvPLAGVFomU_video.jpg
#   inflating: balanced_dataset_default/data/idcvpLCzd2UDU_video.jpg
#   inflating: balanced_dataset_default/data/idcVPLLiDpEJw_video.jpg
#   inflating: balanced_dataset_default/data/idcvPLpbGGiBI_video.jpg
#   inflating: balanced_dataset_default/data/idCvPME6qd6Jo_video.jpg
#   inflating: balanced_dataset_default/data/idcvpnZ8TCcMA_video.jpg
#   inflating: balanced_dataset_default/data/idCVPoexlvXbc_video.jpg
#   inflating: balanced_dataset_default/data/idCVPP0GE5hzc_video.jpg
#   inflating: balanced_dataset_default/data/idCVpqgTxeIpA_video.jpg
#   inflating: balanced_dataset_default/data/idCVPQkoGh2uo_video.jpg
#   inflating: balanced_dataset_default/data/idCVpRkDnNJIY_video.jpg
#   inflating: balanced_dataset_default/data/idcVPsgsXvY_k_video.jpg
#   inflating: balanced_dataset_default/data/idCvPtc08z6YE_video.jpg
#   inflating: balanced_dataset_default/data/idcvptemUtPTg_video.jpg
#   inflating: balanced_dataset_default/data/idcVPtFJ-o1a0_video.jpg
#   inflating: balanced_dataset_default/data/idCvpUDXcNfFc_video.jpg
#   inflating: balanced_dataset_default/data/idcvPULMZVVno_video.jpg
#   inflating: balanced_dataset_default/data/idcvpVrT66Vmc_video.jpg
#   inflating: balanced_dataset_default/data/idcVPySykddD4_video.jpg
#   inflating: balanced_dataset_default/data/idCVpznXOKBGM_video.jpg
#   inflating: balanced_dataset_default/data/idCVp_jXcnaIA_video.jpg
#   inflating: balanced_dataset_default/data/idCvq-2uGJaZ8_video.jpg
#   inflating: balanced_dataset_default/data/idCvQ-dLTseus_video.jpg
#   inflating: balanced_dataset_default/data/idCvQ1Po4p3Vc_video.jpg
#   inflating: balanced_dataset_default/data/idCVQ3H2qKloE_video.jpg
#   inflating: balanced_dataset_default/data/idCvq3uoivxVc_video.jpg
#   inflating: balanced_dataset_default/data/idcVQ40EG9cKQ_video.jpg
#   inflating: balanced_dataset_default/data/idCvQ5ktMSWrs_video.jpg
#   inflating: balanced_dataset_default/data/idcvQ5pdhd1c0_video.jpg
#   inflating: balanced_dataset_default/data/idCVQ8Qm-yk9M_video.jpg
#   inflating: balanced_dataset_default/data/idCvQ8T6ThgdQ_video.jpg
#   inflating: balanced_dataset_default/data/idcVQ9QDVh9Pk_video.jpg
#   inflating: balanced_dataset_default/data/idCvQaI29ykLA_video.jpg
#   inflating: balanced_dataset_default/data/idCvQesw8S4cI_video.jpg
#   inflating: balanced_dataset_default/data/idCVqGg0oyBPE_video.jpg
#   inflating: balanced_dataset_default/data/idcVQJUmIJlrw_video.jpg
#   inflating: balanced_dataset_default/data/idCvQqyRmV-28_video.jpg
#   inflating: balanced_dataset_default/data/idCvQr08FY5Qs_video.jpg
#   inflating: balanced_dataset_default/data/idcVqSHY8dwT8_video.jpg
#   inflating: balanced_dataset_default/data/idcvQXzvZT81U_video.jpg
#   inflating: balanced_dataset_default/data/idCVQZ3wARyoQ_video.jpg
#   inflating: balanced_dataset_default/data/idcvr3a-lR-OA_video.jpg
#   inflating: balanced_dataset_default/data/idcVRK1fyL4Lg_video.jpg
#   inflating: balanced_dataset_default/data/idCvRKZ-DHjGk_video.jpg
#   inflating: balanced_dataset_default/data/idCVRL-wMJGd0_video.jpg
#   inflating: balanced_dataset_default/data/idCvRlnW0XHQo_video.jpg
#   inflating: balanced_dataset_default/data/idCvrnxdJMhU4_video.jpg
#   inflating: balanced_dataset_default/data/idcVRQJL1zlSI_video.jpg
#   inflating: balanced_dataset_default/data/idcvrrgRQAjEU_video.jpg
#   inflating: balanced_dataset_default/data/idCVrrjmYgjt0_video.jpg
#   inflating: balanced_dataset_default/data/idCVRrL6WLizI_video.jpg
#   inflating: balanced_dataset_default/data/idCvRsmHuLt6k_video.jpg
#   inflating: balanced_dataset_default/data/idcVrvmHjviq8_video.jpg
#   inflating: balanced_dataset_default/data/idCVRwL0-GhV4_video.jpg
#   inflating: balanced_dataset_default/data/idcvrZgKh_Ixc_video.jpg
#   inflating: balanced_dataset_default/data/idcVs11XIZbbQ_video.jpg
#   inflating: balanced_dataset_default/data/idCvSByG9LEGw_video.jpg
#   inflating: balanced_dataset_default/data/idcVSF7Lif74Q_video.jpg
#   inflating: balanced_dataset_default/data/idcVSFFNK9lDU_video.jpg
#   inflating: balanced_dataset_default/data/idcvsvu12Ysec_video.jpg
#   inflating: balanced_dataset_default/data/idcvsyKT4FYzo_video.jpg
#   inflating: balanced_dataset_default/data/idcVT53bBA2mY_video.jpg
#   inflating: balanced_dataset_default/data/idCvT5hjnR9js_video.jpg
#   inflating: balanced_dataset_default/data/idCvt7ui07gQs_video.jpg
#   inflating: balanced_dataset_default/data/idCVTeXBxM9Xo_video.jpg
#   inflating: balanced_dataset_default/data/idCVTkbggmxR0_video.jpg
#   inflating: balanced_dataset_default/data/idcvtovfnoXy0_video.jpg
#   inflating: balanced_dataset_default/data/idCvTo_P2zTrs_video.jpg
#   inflating: balanced_dataset_default/data/idCVtP6Z2WpKo_video.jpg
#   inflating: balanced_dataset_default/data/idcVtrLSDRnlg_video.jpg
#   inflating: balanced_dataset_default/data/idCVTvsbca7S0_video.jpg
#   inflating: balanced_dataset_default/data/idcvTZ-G_KHI0_video.jpg
#   inflating: balanced_dataset_default/data/idcVt_M1bY_Sw_video.jpg
#   inflating: balanced_dataset_default/data/idCVU9qEKdXNE_video.jpg
#   inflating: balanced_dataset_default/data/idCvuCQg6yx0c_video.jpg
#   inflating: balanced_dataset_default/data/idcVudCa8dQk0_video.jpg
#   inflating: balanced_dataset_default/data/idcvulAdBq30k_video.jpg
#   inflating: balanced_dataset_default/data/idcVV3QQ3wjC8_video.jpg
#   inflating: balanced_dataset_default/data/idCVWpp9SHQww_video.jpg
#   inflating: balanced_dataset_default/data/idCvXFjn2gSSc_video.jpg
#   inflating: balanced_dataset_default/data/idCVZxvjA2XDk_video.jpg
#   inflating: balanced_dataset_default/data/idcW44BpXpjYw_video.jpg
#   inflating: balanced_dataset_default/data/idcW8j4xvDfi0_video.jpg
#   inflating: balanced_dataset_default/data/idcwb2y51L4oE_video.jpg
#   inflating: balanced_dataset_default/data/idCwB5E72wlBs_video.jpg
#   inflating: balanced_dataset_default/data/idCWBRxA7iwu0_video.jpg
#   inflating: balanced_dataset_default/data/idcwD1rVkf_D8_video.jpg
#   inflating: balanced_dataset_default/data/idCWDgKeP6cNU_video.jpg
#   inflating: balanced_dataset_default/data/idCWdz_pWYNzY_video.jpg
#   inflating: balanced_dataset_default/data/idCWE4FfXeDyc_video.jpg
#   inflating: balanced_dataset_default/data/idcwEnbnY0hl0_video.jpg
#   inflating: balanced_dataset_default/data/idCweROG8S-68_video.jpg
#   inflating: balanced_dataset_default/data/idCwF1Xa1lLnk_video.jpg
#   inflating: balanced_dataset_default/data/idcWgjlNJqMds_video.jpg
#   inflating: balanced_dataset_default/data/idcWgyRyhxIgg_video.jpg
#   inflating: balanced_dataset_default/data/idCWIkOgO8hag_video.jpg
#   inflating: balanced_dataset_default/data/idcwi_fMROJTU_video.jpg
#   inflating: balanced_dataset_default/data/idCwi_L-AePEw_video.jpg
#   inflating: balanced_dataset_default/data/idCwJfgiTOjng_video.jpg
#   inflating: balanced_dataset_default/data/idCWJKyuohiDo_video.jpg
#   inflating: balanced_dataset_default/data/idCWKN93x67wc_video.jpg
#   inflating: balanced_dataset_default/data/idcWKTFuAFcOY_video.jpg
#   inflating: balanced_dataset_default/data/idCWn68_lLRFU_video.jpg
#   inflating: balanced_dataset_default/data/idCWohz92K3O4_video.jpg
#   inflating: balanced_dataset_default/data/idCwOrp6Q7kCE_video.jpg
#   inflating: balanced_dataset_default/data/idCwpcYSq9HNE_video.jpg
#   inflating: balanced_dataset_default/data/idcwpZZG_sH7o_video.jpg
#   inflating: balanced_dataset_default/data/idcwqI8gQZFGw_video.jpg
#   inflating: balanced_dataset_default/data/idCwQzBEU5vFg_video.jpg
#   inflating: balanced_dataset_default/data/idcWS0qmWj9u4_video.jpg
#   inflating: balanced_dataset_default/data/idcWTt2OPK2dM_video.jpg
#   inflating: balanced_dataset_default/data/idcwVfMvvAS_s_video.jpg
#   inflating: balanced_dataset_default/data/idCwvKRFEriSc_video.jpg
#   inflating: balanced_dataset_default/data/idcWX1koBfhwQ_video.jpg
#   inflating: balanced_dataset_default/data/idCwXbWB-Xryc_video.jpg
#   inflating: balanced_dataset_default/data/idCwxYYnYqUpM_video.jpg
#   inflating: balanced_dataset_default/data/idcwyH1D2_5Oo_video.jpg
#   inflating: balanced_dataset_default/data/idCwZbOyP1ep0_video.jpg
#   inflating: balanced_dataset_default/data/idCw_SIM2oQaE_video.jpg
#   inflating: balanced_dataset_default/data/idCxBXMHxwaaU_video.jpg
#   inflating: balanced_dataset_default/data/idcxBXnJr6mS4_video.jpg
#   inflating: balanced_dataset_default/data/idcxBxXcgkd2E_video.jpg
#   inflating: balanced_dataset_default/data/idCXbY4iyr8So_video.jpg
#   inflating: balanced_dataset_default/data/idCxbY4K95a8U_video.jpg
#   inflating: balanced_dataset_default/data/idcxBYGrzr4RI_video.jpg
#   inflating: balanced_dataset_default/data/idcxBYJckKlnI_video.jpg
#   inflating: balanced_dataset_default/data/idcXBYqLyVBcI_video.jpg
#   inflating: balanced_dataset_default/data/idcXbZeWBDpjk_video.jpg
#   inflating: balanced_dataset_default/data/idcXBZHvQevCA_video.jpg
#   inflating: balanced_dataset_default/data/idcXbZiOJbw38_video.jpg
#   inflating: balanced_dataset_default/data/idcxbZiuRwmAs_video.jpg
#   inflating: balanced_dataset_default/data/idcxbzOCM3FO8_video.jpg
#   inflating: balanced_dataset_default/data/idCXBzRS_JuRU_video.jpg
#   inflating: balanced_dataset_default/data/idcxB_L_kmi84_video.jpg
#   inflating: balanced_dataset_default/data/idcXb_o_MPuQk_video.jpg
#   inflating: balanced_dataset_default/data/idcxC-1HDY59s_video.jpg
#   inflating: balanced_dataset_default/data/idCxC-4B-p4BE_video.jpg
#   inflating: balanced_dataset_default/data/idCXc-reo1u30_video.jpg
#   inflating: balanced_dataset_default/data/idcxc0-KQIV2Q_video.jpg
#   inflating: balanced_dataset_default/data/idcxC0g5-7so4_video.jpg
#   inflating: balanced_dataset_default/data/idCxc0iTRPuLA_video.jpg
#   inflating: balanced_dataset_default/data/idcXC0JbV_V4k_video.jpg
#   inflating: balanced_dataset_default/data/idcxc1lBQ7iX8_video.jpg
#   inflating: balanced_dataset_default/data/idCXC1Qmbqmdc_video.jpg
#   inflating: balanced_dataset_default/data/idcXc2CpxXodc_video.jpg
#   inflating: balanced_dataset_default/data/idCxc2jrj3s6w_video.jpg
#   inflating: balanced_dataset_default/data/idCXc2uwSWBkI_video.jpg
#   inflating: balanced_dataset_default/data/idCxc2W85sgoc_video.jpg
#   inflating: balanced_dataset_default/data/idcXc3E7Jhrmk_video.jpg
#   inflating: balanced_dataset_default/data/idCXC40-1xjlQ_video.jpg
#   inflating: balanced_dataset_default/data/idCxc4kT82WO8_video.jpg
#   inflating: balanced_dataset_default/data/idCxC57TNAU-0_video.jpg
#   inflating: balanced_dataset_default/data/idcxC6VoKSW0o_video.jpg
#   inflating: balanced_dataset_default/data/idCXc7EIHj_Zo_video.jpg
#   inflating: balanced_dataset_default/data/idCxc7HAUUmZs_video.jpg
#   inflating: balanced_dataset_default/data/idcxC7UTiktZk_video.jpg
#   inflating: balanced_dataset_default/data/idcxc8h0Ltbzo_video.jpg
#   inflating: balanced_dataset_default/data/idCXc95fnrsIQ_video.jpg
#   inflating: balanced_dataset_default/data/idCXC9WR4lN5s_video.jpg
#   inflating: balanced_dataset_default/data/idCxca3qVCnFY_video.jpg
#   inflating: balanced_dataset_default/data/idCxcA5MpdcPQ_video.jpg
#   inflating: balanced_dataset_default/data/idcxCai-H4234_video.jpg
#   inflating: balanced_dataset_default/data/idCxCANEXrbcI_video.jpg
#   inflating: balanced_dataset_default/data/idCxCASJm0qtk_video.jpg
#   inflating: balanced_dataset_default/data/idcXcAxcGZrfI_video.jpg
#   inflating: balanced_dataset_default/data/idCxcAXPHG8cg_video.jpg
#   inflating: balanced_dataset_default/data/idCxCAYTAFHqs_video.jpg
#   inflating: balanced_dataset_default/data/idCXcbbOXG420_video.jpg
#   inflating: balanced_dataset_default/data/idCxcbk5jfX_U_video.jpg
#   inflating: balanced_dataset_default/data/idcxcbmAUSp-o_video.jpg
#   inflating: balanced_dataset_default/data/idCxCbq5go9ZM_video.jpg
#   inflating: balanced_dataset_default/data/idcxCBrkdghZo_video.jpg
#   inflating: balanced_dataset_default/data/idcxCByvP90NQ_video.jpg
#   inflating: balanced_dataset_default/data/idcxCCaCvdqc0_video.jpg
#   inflating: balanced_dataset_default/data/idcXCcFSy6gMY_video.jpg
#   inflating: balanced_dataset_default/data/idcXcCJ8k-ta8_video.jpg
#   inflating: balanced_dataset_default/data/idCxCckHYK2Bw_video.jpg
#   inflating: balanced_dataset_default/data/idCxCcYHNhIdg_video.jpg
#   inflating: balanced_dataset_default/data/idCXCC_AF1uuI_video.jpg
#   inflating: balanced_dataset_default/data/idcXcd2-Nqw5U_video.jpg
#   inflating: balanced_dataset_default/data/idcxcd9SRax3I_video.jpg
#   inflating: balanced_dataset_default/data/idCXCDkKjAOkg_video.jpg
#   inflating: balanced_dataset_default/data/idcXCdnx_zmX4_video.jpg
#   inflating: balanced_dataset_default/data/idcXcdtUZ2yw8_video.jpg
#   inflating: balanced_dataset_default/data/idCXcD_MrD3nU_video.jpg
#   inflating: balanced_dataset_default/data/idcXCei29miUs_video.jpg
#   inflating: balanced_dataset_default/data/idcXCePuya2j8_video.jpg
#   inflating: balanced_dataset_default/data/idCXcFKI8iUVc_video.jpg
#   inflating: balanced_dataset_default/data/idcxCgCUtuH_0_video.jpg
#   inflating: balanced_dataset_default/data/idCxCGgdZJ54E_video.jpg
#   inflating: balanced_dataset_default/data/idCXcgrOykdhY_video.jpg
#   inflating: balanced_dataset_default/data/idCXcgyNUbmbE_video.jpg
#   inflating: balanced_dataset_default/data/idcxcG_nKnfn8_video.jpg
#   inflating: balanced_dataset_default/data/idCXCH4KEjlYY_video.jpg
#   inflating: balanced_dataset_default/data/idCxChAOVF3hM_video.jpg
#   inflating: balanced_dataset_default/data/idcxcHckYJ5L0_video.jpg
#   inflating: balanced_dataset_default/data/idCXCHDpzcgO8_video.jpg
#   inflating: balanced_dataset_default/data/idCxChf6ICcwI_video.jpg
#   inflating: balanced_dataset_default/data/idcxChNJJk2yY_video.jpg
#   inflating: balanced_dataset_default/data/idCXcHtKbnsLM_video.jpg
#   inflating: balanced_dataset_default/data/idcxCIGZMCSTU_video.jpg
#   inflating: balanced_dataset_default/data/idCxcIuLg-4eo_video.jpg
#   inflating: balanced_dataset_default/data/idcXCkyaVPwGc_video.jpg
#   inflating: balanced_dataset_default/data/idcXclbtVZV3U_video.jpg
#   inflating: balanced_dataset_default/data/idCXClupw6DQU_video.jpg
#   inflating: balanced_dataset_default/data/idCxCmH1VsmQU_video.jpg
#   inflating: balanced_dataset_default/data/idcXCN0QHvvYs_video.jpg
#   inflating: balanced_dataset_default/data/idcxcnKe1sL1M_video.jpg
#   inflating: balanced_dataset_default/data/idcXcoFv867r8_video.jpg
#   inflating: balanced_dataset_default/data/idcxCOlBV9X9g_video.jpg
#   inflating: balanced_dataset_default/data/idCxcoOGO51io_video.jpg
#   inflating: balanced_dataset_default/data/idcXcpf0JQWVc_video.jpg
#   inflating: balanced_dataset_default/data/idCxcpg_8sllU_video.jpg
#   inflating: balanced_dataset_default/data/idcXcpN3q6fqM_video.jpg
#   inflating: balanced_dataset_default/data/idCxCqceDOTEA_video.jpg
#   inflating: balanced_dataset_default/data/idCXcQPr6-6UU_video.jpg
#   inflating: balanced_dataset_default/data/idCxCq_UJgD50_video.jpg
#   inflating: balanced_dataset_default/data/idcxcSRusVXK0_video.jpg
#   inflating: balanced_dataset_default/data/idCxCSs3Nke7Q_video.jpg
#   inflating: balanced_dataset_default/data/idCxCtqAKW_58_video.jpg
#   inflating: balanced_dataset_default/data/idCXcu6yHA0Bk_video.jpg
#   inflating: balanced_dataset_default/data/idcxcu8rp0CmU_video.jpg
#   inflating: balanced_dataset_default/data/idcXCU9Am1kiw_video.jpg
#   inflating: balanced_dataset_default/data/idCxCuKKdH4Es_video.jpg
#   inflating: balanced_dataset_default/data/idCXCuY4ahgO8_video.jpg
#   inflating: balanced_dataset_default/data/idcXcuZV77UJY_video.jpg
#   inflating: balanced_dataset_default/data/idCxCx8WAw_VQ_video.jpg
#   inflating: balanced_dataset_default/data/idCXCXdcmgSFk_video.jpg
#   inflating: balanced_dataset_default/data/idCxcxj4xU_1o_video.jpg
#   inflating: balanced_dataset_default/data/idCxCYbtqv-8Q_video.jpg
#   inflating: balanced_dataset_default/data/idCXCylc44skg_video.jpg
#   inflating: balanced_dataset_default/data/idCxD2831zmFg_video.jpg
#   inflating: balanced_dataset_default/data/idcXD52N9j_hI_video.jpg
#   inflating: balanced_dataset_default/data/idcxd7uihoyVQ_video.jpg
#   inflating: balanced_dataset_default/data/idCXDeQBlx_a0_video.jpg
#   inflating: balanced_dataset_default/data/idCxdmz7AkpVA_video.jpg
#   inflating: balanced_dataset_default/data/idCxdVF_R334U_video.jpg
#   inflating: balanced_dataset_default/data/idcxDz0Z066NI_video.jpg
#   inflating: balanced_dataset_default/data/idcxeaARH_jcM_video.jpg
#   inflating: balanced_dataset_default/data/idcxEagggMQh8_video.jpg
#   inflating: balanced_dataset_default/data/idCXemPWXOhek_video.jpg
#   inflating: balanced_dataset_default/data/idCXerF6crDRs_video.jpg
#   inflating: balanced_dataset_default/data/idCXESHICqTWU_video.jpg
#   inflating: balanced_dataset_default/data/idCxey_-bt2cQ_video.jpg
#   inflating: balanced_dataset_default/data/idCxF2Zi5Tpz0_video.jpg
#   inflating: balanced_dataset_default/data/idCxf7h3c2gzU_video.jpg
#   inflating: balanced_dataset_default/data/idcxFAiy3wSwY_video.jpg
#   inflating: balanced_dataset_default/data/idCXFFOadnQsM_video.jpg
#   inflating: balanced_dataset_default/data/idCXFgtApFAsw_video.jpg
#   inflating: balanced_dataset_default/data/idcxfiEhr3l9w_video.jpg
#   inflating: balanced_dataset_default/data/idCXFlA4hJ_yE_video.jpg
#   inflating: balanced_dataset_default/data/idCxflDjfBdoI_video.jpg
#   inflating: balanced_dataset_default/data/idCxFMMIYLtSg_video.jpg
#   inflating: balanced_dataset_default/data/idcxfMpmmYWNM_video.jpg
#   inflating: balanced_dataset_default/data/idCXFuJjBooZM_video.jpg
#   inflating: balanced_dataset_default/data/idCxfxO8QzKxk_video.jpg
#   inflating: balanced_dataset_default/data/idCXFXsNqJ2M8_video.jpg
#   inflating: balanced_dataset_default/data/idCXFZMGddENA_video.jpg
#   inflating: balanced_dataset_default/data/idcXg1VrhUi2I_video.jpg
#   inflating: balanced_dataset_default/data/idcxgc34p4Qag_video.jpg
#   inflating: balanced_dataset_default/data/idCxGiLWC4BRY_video.jpg
#   inflating: balanced_dataset_default/data/idcXgOpZCfXwo_video.jpg
#   inflating: balanced_dataset_default/data/idCxGPlJOwI4o_video.jpg
#   inflating: balanced_dataset_default/data/idcXGQpuXtEU0_video.jpg
#   inflating: balanced_dataset_default/data/idCXgSs65N7LM_video.jpg
#   inflating: balanced_dataset_default/data/idcXgU-_VPaIE_video.jpg
#   inflating: balanced_dataset_default/data/idCxGzgukwkG8_video.jpg
#   inflating: balanced_dataset_default/data/idCXG_PYKp4S0_video.jpg
#   inflating: balanced_dataset_default/data/idCxHaI1wN7Ig_video.jpg
#   inflating: balanced_dataset_default/data/idCXhbTgWpntM_video.jpg
#   inflating: balanced_dataset_default/data/idcxHc0FBCS60_video.jpg
#   inflating: balanced_dataset_default/data/idCxHC0otEe6I_video.jpg
#   inflating: balanced_dataset_default/data/idCxhIjrI2mnQ_video.jpg
#   inflating: balanced_dataset_default/data/idCXhqAgPxUNA_video.jpg
#   inflating: balanced_dataset_default/data/idcXHUYl0I3mw_video.jpg
#   inflating: balanced_dataset_default/data/idCXIqTY5YrRI_video.jpg
#   inflating: balanced_dataset_default/data/idcxlf-ZmE8JI_video.jpg
#   inflating: balanced_dataset_default/data/idcXlFr2h94i4_video.jpg
#   inflating: balanced_dataset_default/data/idcXllyl05O04_video.jpg
#   inflating: balanced_dataset_default/data/idcXLpq--d898_video.jpg
#   inflating: balanced_dataset_default/data/idCxMoxNVMIXE_video.jpg
#   inflating: balanced_dataset_default/data/idCxnaPa8ohmM_video.jpg
#   inflating: balanced_dataset_default/data/idCxNXRYS-G6M_video.jpg
#   inflating: balanced_dataset_default/data/idcxouQjHEpC4_video.jpg
#   inflating: balanced_dataset_default/data/idCXpf8PYH_Mg_video.jpg
#   inflating: balanced_dataset_default/data/idCxrHJgTZjag_video.jpg
#   inflating: balanced_dataset_default/data/idcXsD5sjV_40_video.jpg
#   inflating: balanced_dataset_default/data/idCXTAkwMqtEc_video.jpg
#   inflating: balanced_dataset_default/data/idCxTqEsmzkC4_video.jpg
#   inflating: balanced_dataset_default/data/idCXtWD1ZFvwY_video.jpg
#   inflating: balanced_dataset_default/data/idcXuC_v0KWaU_video.jpg
#   inflating: balanced_dataset_default/data/idCXusHXYMz_A_video.jpg
#   inflating: balanced_dataset_default/data/idCxvh9qwSqLQ_video.jpg
#   inflating: balanced_dataset_default/data/idcxwA-GYj6zI_video.jpg
#   inflating: balanced_dataset_default/data/idcXXw-uvr_4Y_video.jpg
#   inflating: balanced_dataset_default/data/idCXy8lpqzlRU_video.jpg
#   inflating: balanced_dataset_default/data/idcxypqQx53ec_video.jpg
#   inflating: balanced_dataset_default/data/idCxZ2gKfXUII_video.jpg
#   inflating: balanced_dataset_default/data/idCx_ezJK6bek_video.jpg
#   inflating: balanced_dataset_default/data/idCY0PeoViypU_video.jpg
#   inflating: balanced_dataset_default/data/idcy1NB1Zr-uU_video.jpg
#   inflating: balanced_dataset_default/data/idCY249g4jfw4_video.jpg
#   inflating: balanced_dataset_default/data/idcY29WpVTO44_video.jpg
#   inflating: balanced_dataset_default/data/idcY3zyFSoD5E_video.jpg
#   inflating: balanced_dataset_default/data/idcy5AyGT5TfE_video.jpg
#   inflating: balanced_dataset_default/data/idcy7RtpF_0kk_video.jpg
#   inflating: balanced_dataset_default/data/idCy8quyN33V8_video.jpg
#   inflating: balanced_dataset_default/data/idCyaI6EsWwt8_video.jpg
#   inflating: balanced_dataset_default/data/idcYBtvRQgJYA_video.jpg
#   inflating: balanced_dataset_default/data/idCYCfEKuxXbA_video.jpg
#   inflating: balanced_dataset_default/data/idcyCUvWKeMeg_video.jpg
#   inflating: balanced_dataset_default/data/idcyd8ihhu60o_video.jpg
#   inflating: balanced_dataset_default/data/idCyDuGv_1GDY_video.jpg
#   inflating: balanced_dataset_default/data/idcydxlhvpIbs_video.jpg
#   inflating: balanced_dataset_default/data/idCye-1RP5jso_video.jpg
#   inflating: balanced_dataset_default/data/idcyEaTvTSu38_video.jpg
#   inflating: balanced_dataset_default/data/idCYequ--sZZE_video.jpg
#   inflating: balanced_dataset_default/data/idCYFdrIsqFDw_video.jpg
#   inflating: balanced_dataset_default/data/idcyFsQS-sA10_video.jpg
#   inflating: balanced_dataset_default/data/idCyVqTTjobvU_video.jpg
#   inflating: balanced_dataset_default/data/idcYVqve5-mII_video.jpg
#   inflating: balanced_dataset_default/data/idCYVr0HI78nU_video.jpg
#   inflating: balanced_dataset_default/data/idcyvR4mnOeYo_video.jpg
#   inflating: balanced_dataset_default/data/idCyVRNs8PlPg_video.jpg
#   inflating: balanced_dataset_default/data/idCYVrslxF2hQ_video.jpg
#   inflating: balanced_dataset_default/data/idCYVsbue9MPQ_video.jpg
#   inflating: balanced_dataset_default/data/idCYVSC6RkAeg_video.jpg
#   inflating: balanced_dataset_default/data/idcYvSftBpcsc_video.jpg
#   inflating: balanced_dataset_default/data/idCyVSFTY5Fpc_video.jpg
#   inflating: balanced_dataset_default/data/idCyvspegQ1V4_video.jpg
#   inflating: balanced_dataset_default/data/idCYVsWmpil4c_video.jpg
#   inflating: balanced_dataset_default/data/idCyvsWRKZd7M_video.jpg
#   inflating: balanced_dataset_default/data/idCyvt83hEOKo_video.jpg
#   inflating: balanced_dataset_default/data/idCyvtPePzoaM_video.jpg
#   inflating: balanced_dataset_default/data/idcYVTpIcPTfg_video.jpg
#   inflating: balanced_dataset_default/data/idCYVTpsgkxo0_video.jpg
#   inflating: balanced_dataset_default/data/idcYVueXNjuSw_video.jpg
#   inflating: balanced_dataset_default/data/idcYVuM2vWq2k_video.jpg
#   inflating: balanced_dataset_default/data/idCYvUMrWbUfM_video.jpg
#   inflating: balanced_dataset_default/data/idCYVUnOGBWy0_video.jpg
#   inflating: balanced_dataset_default/data/idCYvuoNnLf8U_video.jpg
#   inflating: balanced_dataset_default/data/idcYvuQiD4uQk_video.jpg
#   inflating: balanced_dataset_default/data/idcYvuR1RK6p8_video.jpg
#   inflating: balanced_dataset_default/data/idcYVUSdFE7f0_video.jpg
#   inflating: balanced_dataset_default/data/idCYVutMm7bPQ_video.jpg
#   inflating: balanced_dataset_default/data/idcyvUvx3uv2M_video.jpg
#   inflating: balanced_dataset_default/data/idcyvuXQA4HIg_video.jpg
#   inflating: balanced_dataset_default/data/idCyVvfQtJ9qY_video.jpg
#   inflating: balanced_dataset_default/data/idCYvvQ0cchvg_video.jpg
#   inflating: balanced_dataset_default/data/idcyVvR0yIaHI_video.jpg
#   inflating: balanced_dataset_default/data/idcYvW5bCNNvc_video.jpg
#   inflating: balanced_dataset_default/data/idCyVWeBveu38_video.jpg
#   inflating: balanced_dataset_default/data/idCyvwEwHZJec_video.jpg
#   inflating: balanced_dataset_default/data/idCYVWl8bIvqw_video.jpg
#   inflating: balanced_dataset_default/data/idCyvWPQ01U5w_video.jpg
#   inflating: balanced_dataset_default/data/idCYVx-cM_rKM_video.jpg
#   inflating: balanced_dataset_default/data/idCYVx7evnNlk_video.jpg
#   inflating: balanced_dataset_default/data/idcyVXCsPtydg_video.jpg
#   inflating: balanced_dataset_default/data/idcyvXKmm0W4Y_video.jpg
#   inflating: balanced_dataset_default/data/idCYVxm4gpEvM_video.jpg
#   inflating: balanced_dataset_default/data/idCYvXog8adjQ_video.jpg
#   inflating: balanced_dataset_default/data/idcYvYK2CQ0Yg_video.jpg
#   inflating: balanced_dataset_default/data/idcYvZGc0zK4s_video.jpg
#   inflating: balanced_dataset_default/data/idcYvZjO4kCyI_video.jpg
#   inflating: balanced_dataset_default/data/idCyvZom26Uek_video.jpg
#   inflating: balanced_dataset_default/data/idcyv_0QZutyc_video.jpg
#   inflating: balanced_dataset_default/data/idcyV_O7VhKgM_video.jpg
#   inflating: balanced_dataset_default/data/idCYw-2sCxbdc_video.jpg
#   inflating: balanced_dataset_default/data/idcyw0-YaiXkA_video.jpg
#   inflating: balanced_dataset_default/data/idCYw0GN6KEfs_video.jpg
#   inflating: balanced_dataset_default/data/idcyw0keelPhM_video.jpg
#   inflating: balanced_dataset_default/data/idcYw0U8FoQPY_video.jpg
#   inflating: balanced_dataset_default/data/idcYW0_dyR59Y_video.jpg
#   inflating: balanced_dataset_default/data/idCYw17QAI2k8_video.jpg
#   inflating: balanced_dataset_default/data/idcyw1I0JUK44_video.jpg
#   inflating: balanced_dataset_default/data/idcYW1s1rKa0o_video.jpg
#   inflating: balanced_dataset_default/data/idcYw2UVuVMzA_video.jpg
#   inflating: balanced_dataset_default/data/idCYW3D_g4ugg_video.jpg
#   inflating: balanced_dataset_default/data/idCyw3mZMmqVc_video.jpg
#   inflating: balanced_dataset_default/data/idcyW44046uXA_video.jpg
#   inflating: balanced_dataset_default/data/idcYW4dkak6VY_video.jpg
#   inflating: balanced_dataset_default/data/idcYW4IZjl_mw_video.jpg
#   inflating: balanced_dataset_default/data/idCyW53N9euoA_video.jpg
#   inflating: balanced_dataset_default/data/idcYw5PoUv7U0_video.jpg
#   inflating: balanced_dataset_default/data/idcYW5yt699CI_video.jpg
#   inflating: balanced_dataset_default/data/idCYW60OsW1sk_video.jpg
#   inflating: balanced_dataset_default/data/idCYW6Jy5N9Fc_video.jpg
#   inflating: balanced_dataset_default/data/idcYW6lzN0gdE_video.jpg
#   inflating: balanced_dataset_default/data/idCYw8xasH_AA_video.jpg
#   inflating: balanced_dataset_default/data/idCYWBWSXScVE_video.jpg
#   inflating: balanced_dataset_default/data/idCyWCpXuJTeA_video.jpg
#   inflating: balanced_dataset_default/data/idCYWCToYGn4k_video.jpg
#   inflating: balanced_dataset_default/data/idcYwdqIEgKvE_video.jpg
#   inflating: balanced_dataset_default/data/idCYWebg0zBxk_video.jpg
#   inflating: balanced_dataset_default/data/idCywei2LFxjU_video.jpg
#   inflating: balanced_dataset_default/data/idCYwFbjlALpQ_video.jpg
#   inflating: balanced_dataset_default/data/idCywfPLfpFB4_video.jpg
#   inflating: balanced_dataset_default/data/idCywGY49m0mg_video.jpg
#   inflating: balanced_dataset_default/data/idCYWH-IdgtmI_video.jpg
#   inflating: balanced_dataset_default/data/idcYwH3Xw4vQg_video.jpg
#   inflating: balanced_dataset_default/data/idCYwH6yzPs_U_video.jpg
#   inflating: balanced_dataset_default/data/idcYwhYBiOmUM_video.jpg
#   inflating: balanced_dataset_default/data/idCywIjFa2xao_video.jpg
#   inflating: balanced_dataset_default/data/idCYWIP9XRLFI_video.jpg
#   inflating: balanced_dataset_default/data/idCywJD13fujw_video.jpg
#   inflating: balanced_dataset_default/data/idCywJqG-iYF0_video.jpg
#   inflating: balanced_dataset_default/data/idcyWJT_PQw8s_video.jpg
# ...
#   inflating: balanced_dataset_default/data/iddzqoDNHzi80_video.jpg
#   inflating: balanced_dataset_default/data/idDZrd4aifqMI_video.jpg
#   inflating: balanced_dataset_default/data/iddZRHO0d9Nao_video.jpg
#   inflating: balanced_dataset_default/data/idDzTsJdgWWXc_video.jpg
#   inflating: balanced_dataset_default/data/iddzudcm-ywJo_video.jpg
#   inflating: balanced_dataset_default/data/idDZui-LOEO34_video.jpg
#   inflating: balanced_dataset_default/data/idDZUQopDhbxg_video.jpg
#   inflating: balanced_dataset_default/data/idDZWDbdW-tvk_video.jpg
#   inflating: balanced_dataset_default/data/idDzWHacQyZtw_video.jpg
#   inflating: balanced_dataset_default/data/iddzxVA-Lwoz4_video.jpg
#   inflating: balanced_dataset_default/data/idD_0KrTwwRQ8_video.jpg
#   inflating: balanced_dataset_default/data/idd_1KADmgsjs_video.jpg
#   inflating: balanced_dataset_default/data/idd_1REHxLoqM_video.jpg
#   inflating: balanced_dataset_default/data/idd_1sKG30krE_video.jpg
#   inflating: balanced_dataset_default/data/idD_87hql1jSw_video.jpg
#   inflating: balanced_dataset_default/data/idd_ArDL86jVI_video.jpg
#   inflating: balanced_dataset_default/data/idd_AwyTp9qb0_video.jpg
#   inflating: balanced_dataset_default/data/idd_CptclBivc_video.jpg
#   inflating: balanced_dataset_default/data/idd_Dere_bZrw_video.jpg
#   inflating: balanced_dataset_default/data/idd_dH4qmQZ8U_video.jpg
#   inflating: balanced_dataset_default/data/idD_EgCmmWmUI_video.jpg
#   inflating: balanced_dataset_default/data/idd_JQsTG6joc_video.jpg
#   inflating: balanced_dataset_default/data/idd_k5DUi_FqE_video.jpg
#   inflating: balanced_dataset_default/data/idD_M74wW67gQ_video.jpg
#   inflating: balanced_dataset_default/data/idd_rcNp9qqyw_video.jpg
#   inflating: balanced_dataset_default/data/idD_Ru7khHSdM_video.jpg
#   inflating: balanced_dataset_default/data/idd_RZldNnJPk_video.jpg
#   inflating: balanced_dataset_default/data/idD_SyYuIg0Wk_video.jpg
#   inflating: balanced_dataset_default/data/idd_tC8ghwNKY_video.jpg
#   inflating: balanced_dataset_default/data/idd_vC2pwJvWE_video.jpg
#   inflating: balanced_dataset_default/data/idd_w7932a37M_video.jpg
#   inflating: balanced_dataset_default/data/idE-W6G1O7xrc_video.jpg
#   inflating: balanced_dataset_default/data/ide-W6LnQYIaw_video.jpg
#   inflating: balanced_dataset_default/data/idE-w8E75dFzw_video.jpg
#   inflating: balanced_dataset_default/data/ide-wA0Mmwgl4_video.jpg
#   inflating: balanced_dataset_default/data/ide-wa7vka29w_video.jpg
#   inflating: balanced_dataset_default/data/ide-wAjqhw2kA_video.jpg
#   inflating: balanced_dataset_default/data/idE-WaOdv9XtM_video.jpg
#   inflating: balanced_dataset_default/data/ide-waS9S3s2g_video.jpg
#   inflating: balanced_dataset_default/data/ide-WAYli0AJg_video.jpg
#   inflating: balanced_dataset_default/data/ide-Wb-4Ie8sI_video.jpg
#   inflating: balanced_dataset_default/data/ide-wbAV-UwGU_video.jpg
#   inflating: balanced_dataset_default/data/idE-Wbmkh9BNo_video.jpg
#   inflating: balanced_dataset_default/data/ide-wBVSmn848_video.jpg
#   inflating: balanced_dataset_default/data/ide-WcgPVQYF8_video.jpg
#   inflating: balanced_dataset_default/data/idE-WCOiG53r8_video.jpg
#   inflating: balanced_dataset_default/data/idE-wCOjy9XME_video.jpg
#   inflating: balanced_dataset_default/data/ide-wDo_HpOak_video.jpg
#   inflating: balanced_dataset_default/data/idE-We7IGV5zg_video.jpg
#   inflating: balanced_dataset_default/data/ide-wEEEIo9wA_video.jpg
#   inflating: balanced_dataset_default/data/idE-WENn2aoQA_video.jpg
#   inflating: balanced_dataset_default/data/ide-Wev5rkeqQ_video.jpg
#   inflating: balanced_dataset_default/data/idE-wfJ2co8ZA_video.jpg
#   inflating: balanced_dataset_default/data/idE-WFSAhNHps_video.jpg
#   inflating: balanced_dataset_default/data/idE-wF_hf0pL0_video.jpg
#   inflating: balanced_dataset_default/data/ide-wf_hfs9sY_video.jpg
#   inflating: balanced_dataset_default/data/ide-WGIdD_Qcc_video.jpg
#   inflating: balanced_dataset_default/data/idE-WgS7C_JL4_video.jpg
#   inflating: balanced_dataset_default/data/idE-whncNPhpc_video.jpg
#   inflating: balanced_dataset_default/data/idE-wHXNoFKBY_video.jpg
#   inflating: balanced_dataset_default/data/idE-Wi-POQpVU_video.jpg
#   inflating: balanced_dataset_default/data/ide-wi39W7g04_video.jpg
#   inflating: balanced_dataset_default/data/idE-wi4jpST_M_video.jpg
#   inflating: balanced_dataset_default/data/ide-wiho-8vGk_video.jpg
#   inflating: balanced_dataset_default/data/ide-wj4D_HN_o_video.jpg
#   inflating: balanced_dataset_default/data/ide-wJNk2xagk_video.jpg
#   inflating: balanced_dataset_default/data/ide-wjvtpL8GU_video.jpg
#   inflating: balanced_dataset_default/data/idE-WJw_4KABA_video.jpg
#   inflating: balanced_dataset_default/data/idE-wKTLHlMAg_video.jpg
#   inflating: balanced_dataset_default/data/ide-wlglBI5QU_video.jpg
#   inflating: balanced_dataset_default/data/idE-WM21Stv6U_video.jpg
#   inflating: balanced_dataset_default/data/ide-WmjYVEhMA_video.jpg
#   inflating: balanced_dataset_default/data/idE-WMkB3KZq4_video.jpg
#   inflating: balanced_dataset_default/data/ide-WMSYDWyW0_video.jpg
#   inflating: balanced_dataset_default/data/ide-woygq4cSs_video.jpg
#   inflating: balanced_dataset_default/data/ide-WPGRUsO2c_video.jpg
#   inflating: balanced_dataset_default/data/idE-wPIs8U1Qk_video.jpg
#   inflating: balanced_dataset_default/data/idE-WpJQ3jpz4_video.jpg
#   inflating: balanced_dataset_default/data/idE-WPMARn3qU_video.jpg
#   inflating: balanced_dataset_default/data/ide-WqGvEbgcE_video.jpg
#   inflating: balanced_dataset_default/data/ide-wqiR3nXeg_video.jpg
#   inflating: balanced_dataset_default/data/idE-WQxPKF_uY_video.jpg
#   inflating: balanced_dataset_default/data/idE-ws5wzH_Y4_video.jpg
#   inflating: balanced_dataset_default/data/idE-wSCHdCPtw_video.jpg
#   inflating: balanced_dataset_default/data/ide-Wsvy5mOks_video.jpg
#   inflating: balanced_dataset_default/data/ide-WSzr1Nwkc_video.jpg
#   inflating: balanced_dataset_default/data/ide-Wt0zzciYM_video.jpg
#   inflating: balanced_dataset_default/data/idE-wtEe0PAiI_video.jpg
#   inflating: balanced_dataset_default/data/idE-wtNqn8FHw_video.jpg
#   inflating: balanced_dataset_default/data/ide-Wu6JnVHlU_video.jpg
#   inflating: balanced_dataset_default/data/idE-wuFqHWx38_video.jpg
#   inflating: balanced_dataset_default/data/ide-wutxdEPR0_video.jpg
#   inflating: balanced_dataset_default/data/ide-wuvrFLNFc_video.jpg
#   inflating: balanced_dataset_default/data/idE-wvbN654y0_video.jpg
#   inflating: balanced_dataset_default/data/ide-Wvoc7yuQw_video.jpg
#   inflating: balanced_dataset_default/data/ide-WWmzU_NOs_video.jpg
#   inflating: balanced_dataset_default/data/idE-WXlK2eMTY_video.jpg
#   inflating: balanced_dataset_default/data/idE-wy4Mqj_jI_video.jpg
#   inflating: balanced_dataset_default/data/idE-wYbmqoGIs_video.jpg
#   inflating: balanced_dataset_default/data/idE-WyfhixoXU_video.jpg
#   inflating: balanced_dataset_default/data/ide-WYJ5vGahM_video.jpg
#   inflating: balanced_dataset_default/data/ide-WYO9cNcbU_video.jpg
#   inflating: balanced_dataset_default/data/idE-WYUR-x3ZU_video.jpg
#   inflating: balanced_dataset_default/data/idE-X-hBKzez8_video.jpg
#   inflating: balanced_dataset_default/data/idE-X1pNRUNuU_video.jpg
#   inflating: balanced_dataset_default/data/idE-X232-JuK8_video.jpg
#   inflating: balanced_dataset_default/data/idE-x3DIo8SYQ_video.jpg
#   inflating: balanced_dataset_default/data/ide-X42je7CAI_video.jpg
#   inflating: balanced_dataset_default/data/ide-X4bGtf28c_video.jpg
#   inflating: balanced_dataset_default/data/idE-X5XYZnCEk_video.jpg
#   inflating: balanced_dataset_default/data/idE-x7oEHlsfs_video.jpg
#   inflating: balanced_dataset_default/data/idE-xAS3b_b-g_video.jpg
#   inflating: balanced_dataset_default/data/idE-XaXkCpfJY_video.jpg
#   inflating: balanced_dataset_default/data/ide-xb9OU86Zw_video.jpg
#   inflating: balanced_dataset_default/data/idE-XDLji0Vzc_video.jpg
#   inflating: balanced_dataset_default/data/ide-xfTmDSoHk_video.jpg
#   inflating: balanced_dataset_default/data/ide-xFUbiVIcI_video.jpg
#   inflating: balanced_dataset_default/data/ide-xGG78EsK4_video.jpg
#   inflating: balanced_dataset_default/data/ide-xgO6zXCaM_video.jpg
#   inflating: balanced_dataset_default/data/ide-XgQJQLP7Q_video.jpg
#   inflating: balanced_dataset_default/data/idE-XhGQCcc-8_video.jpg
#   inflating: balanced_dataset_default/data/idE-XiESRbYk8_video.jpg
#   inflating: balanced_dataset_default/data/idE-XiwapKeps_video.jpg
#   inflating: balanced_dataset_default/data/idE-XJS5sY9os_video.jpg
#   inflating: balanced_dataset_default/data/idE-XMmdZyrtk_video.jpg
#   inflating: balanced_dataset_default/data/ide-xnbj9Io1M_video.jpg
#   inflating: balanced_dataset_default/data/ide-xOamlEvV8_video.jpg
#   inflating: balanced_dataset_default/data/ide-XPgyxDLJk_video.jpg
#   inflating: balanced_dataset_default/data/ide-xPJy7_HAo_video.jpg
#   inflating: balanced_dataset_default/data/idE-XRhz5SwAk_video.jpg
#   inflating: balanced_dataset_default/data/ide-XSvyjdpdI_video.jpg
#   inflating: balanced_dataset_default/data/idE-xTvGdHpUA_video.jpg
#   inflating: balanced_dataset_default/data/ide-XViAchqYs_video.jpg
#   inflating: balanced_dataset_default/data/ide-XX6Ldhnv0_video.jpg
#   inflating: balanced_dataset_default/data/idE-xXgThVCIM_video.jpg
#   inflating: balanced_dataset_default/data/idE-xyd1ZVC0A_video.jpg
#   inflating: balanced_dataset_default/data/ide-Y-SCrIg0s_video.jpg
#   inflating: balanced_dataset_default/data/idE-Y15iAsn7Q_video.jpg
#   inflating: balanced_dataset_default/data/idE-y2ok_h568_video.jpg
#   inflating: balanced_dataset_default/data/ide-yd_uq-zuM_video.jpg
#   inflating: balanced_dataset_default/data/ide-YJ7Hfeu8A_video.jpg
#   inflating: balanced_dataset_default/data/ide-YKsYuYF2Y_video.jpg
#   inflating: balanced_dataset_default/data/idE-YlDldD124_video.jpg
#   inflating: balanced_dataset_default/data/ide-yuqhK-WLw_video.jpg
#   inflating: balanced_dataset_default/data/idE-Z5wxpJAJo_video.jpg
#   inflating: balanced_dataset_default/data/ide-z9jgXxR3A_video.jpg
#   inflating: balanced_dataset_default/data/ide-z9zfj5b5M_video.jpg
#   inflating: balanced_dataset_default/data/idE-ZFRXKIVxY_video.jpg
#   inflating: balanced_dataset_default/data/idE-zielZnUrY_video.jpg
#   inflating: balanced_dataset_default/data/ide-ZVXHnABPg_video.jpg
#   inflating: balanced_dataset_default/data/ide-_4j_KvV_Q_video.jpg
#   inflating: balanced_dataset_default/data/ide-_AfWaUCXs_video.jpg
#   inflating: balanced_dataset_default/data/idE-_TdpQTPfk_video.jpg
#   inflating: balanced_dataset_default/data/ide0-RZIyW5HY_video.jpg
#   inflating: balanced_dataset_default/data/idE0-xrivdJWA_video.jpg
#   inflating: balanced_dataset_default/data/idE0-Z5N1GwiA_video.jpg
#   inflating: balanced_dataset_default/data/ide00xNDNTF54_video.jpg
#   inflating: balanced_dataset_default/data/idE00ZwKHi0Cg_video.jpg
#   inflating: balanced_dataset_default/data/ide02L_N-IJzo_video.jpg
#   inflating: balanced_dataset_default/data/ide02MM3T0jcc_video.jpg
#   inflating: balanced_dataset_default/data/ide04_SLpcym8_video.jpg
#   inflating: balanced_dataset_default/data/idE05e85VZCAc_video.jpg
#   inflating: balanced_dataset_default/data/idE05EObQIMlw_video.jpg
#   inflating: balanced_dataset_default/data/ide05w3WTFXZE_video.jpg
#   inflating: balanced_dataset_default/data/ide06tSoVbHRM_video.jpg
#   inflating: balanced_dataset_default/data/idE06Ur0ICDeg_video.jpg
#   inflating: balanced_dataset_default/data/ide07jE1GcNX8_video.jpg
#   inflating: balanced_dataset_default/data/ide07kZBaqVUY_video.jpg
#   inflating: balanced_dataset_default/data/ide08bMjMu6nA_video.jpg
#   inflating: balanced_dataset_default/data/ide08nuO19cU0_video.jpg
#   inflating: balanced_dataset_default/data/ide08SSTkqyPw_video.jpg
#   inflating: balanced_dataset_default/data/idE08ybl7KeSQ_video.jpg
#   inflating: balanced_dataset_default/data/ide09nbSAfxe0_video.jpg
#   inflating: balanced_dataset_default/data/ide0a7dR8Q7kg_video.jpg
#   inflating: balanced_dataset_default/data/idE0AaqQkicfU_video.jpg
#   inflating: balanced_dataset_default/data/idE0AFABIofcU_video.jpg
#   inflating: balanced_dataset_default/data/idE0aKIqoNNww_video.jpg
#   inflating: balanced_dataset_default/data/idE0ASaYAA7oo_video.jpg
#   inflating: balanced_dataset_default/data/idE0ATUHxVKPo_video.jpg
#   inflating: balanced_dataset_default/data/idE0bE_imeCEM_video.jpg
#   inflating: balanced_dataset_default/data/ide0bG7qmMc9c_video.jpg
#   inflating: balanced_dataset_default/data/idE0bvw8BvKH4_video.jpg
#   inflating: balanced_dataset_default/data/ide0c0w8aw8Yk_video.jpg
#   inflating: balanced_dataset_default/data/idE0CDO4SDuAs_video.jpg
#   inflating: balanced_dataset_default/data/ide0cDRN35QcM_video.jpg
#   inflating: balanced_dataset_default/data/idE0fZp34pyy8_video.jpg
#   inflating: balanced_dataset_default/data/idE0Ge4nAct_M_video.jpg
#   inflating: balanced_dataset_default/data/ide0gJEaBjzp0_video.jpg
#   inflating: balanced_dataset_default/data/ide0gpNtYLUbM_video.jpg
#   inflating: balanced_dataset_default/data/idE0GWndrXq0o_video.jpg
#   inflating: balanced_dataset_default/data/idE0i9iRTborU_video.jpg
#   inflating: balanced_dataset_default/data/ide0JoCqLCl5M_video.jpg
#   inflating: balanced_dataset_default/data/ide0jpUPLqLhA_video.jpg
#   inflating: balanced_dataset_default/data/ide0OL2q-AHyw_video.jpg
#   inflating: balanced_dataset_default/data/idE0qjNgX70Fg_video.jpg
#   inflating: balanced_dataset_default/data/ide0RefTHud-g_video.jpg
#   inflating: balanced_dataset_default/data/ide0RSrr1o_ro_video.jpg
#   inflating: balanced_dataset_default/data/ide0TInLOJuUM_video.jpg
#   inflating: balanced_dataset_default/data/ide0TjGkSixWo_video.jpg
#   inflating: balanced_dataset_default/data/ide0UUmTARaOc_video.jpg
#   inflating: balanced_dataset_default/data/ide0W1OF-2ImQ_video.jpg
#   inflating: balanced_dataset_default/data/idE0XRi-ebs-Q_video.jpg
#   inflating: balanced_dataset_default/data/ide0YecIZlpHU_video.jpg
#   inflating: balanced_dataset_default/data/ide12s53HmuUk_video.jpg
#   inflating: balanced_dataset_default/data/ide16L1078np8_video.jpg
#   inflating: balanced_dataset_default/data/idE17HnEMloDc_video.jpg
#   inflating: balanced_dataset_default/data/idE17IRO8--ag_video.jpg
#   inflating: balanced_dataset_default/data/ide1AIJ4kdoNk_video.jpg
#   inflating: balanced_dataset_default/data/idE1fzJ_AYajA_video.jpg
#   inflating: balanced_dataset_default/data/ide1H9B2HWzpA_video.jpg
#   inflating: balanced_dataset_default/data/ide1hSKWKPSyg_video.jpg
#   inflating: balanced_dataset_default/data/ide1l0jVTpDrc_video.jpg
#   inflating: balanced_dataset_default/data/ide1PFFPjzIgc_video.jpg
#   inflating: balanced_dataset_default/data/idE1pYIa3LYgo_video.jpg
#   inflating: balanced_dataset_default/data/idE1vHZ2spCJg_video.jpg
#   inflating: balanced_dataset_default/data/idE1VxtpcpHd0_video.jpg
#   inflating: balanced_dataset_default/data/idE1wg2JVLlCU_video.jpg
#   inflating: balanced_dataset_default/data/idE1Y-vBwh1DQ_video.jpg
#   inflating: balanced_dataset_default/data/idE1yxOJHhFb8_video.jpg
#   inflating: balanced_dataset_default/data/ide1zLg4itgZA_video.jpg
#   inflating: balanced_dataset_default/data/ide21NgM0MJSk_video.jpg
#   inflating: balanced_dataset_default/data/ide22ieUuCDRc_video.jpg
#   inflating: balanced_dataset_default/data/idE2aUFPG4uiQ_video.jpg
#   inflating: balanced_dataset_default/data/ide2CUNNyL7pQ_video.jpg
#   inflating: balanced_dataset_default/data/ide2Dzlj4-M1c_video.jpg
#   inflating: balanced_dataset_default/data/idE2EfGAVZvOI_video.jpg
#   inflating: balanced_dataset_default/data/idE2gK1mLbJKE_video.jpg
#   inflating: balanced_dataset_default/data/ide2hvBdWy0X8_video.jpg
#   inflating: balanced_dataset_default/data/ide2jPLqvMRwM_video.jpg
#   inflating: balanced_dataset_default/data/ide2JR9LtAic0_video.jpg
#   inflating: balanced_dataset_default/data/ide2lDHnV9P1Y_video.jpg
#   inflating: balanced_dataset_default/data_info.csv

# %%
# Librerias utilizadas.
import pandas as pd
import numpy as np
import tensorflow as tf
from skimage import io
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Input,MaxPooling2D, Dropout

# %%
# Generador de datos
class DataGenerator(Sequence):

  # imgIDs: Lista de las ID de las imagenes a utilizar en este generator.
  # labels: Diccionario de los labels para cada ID (sin one hot encoding)
  # batch_size: Tamaño de cada batch que se genera por llamado.
  # dim: Dimensiones de las imagenes.
  # n_channels: Numero de canales de la imagen.
  # n_classes: Numero de labels distintos.
  # shuffle: Si revolver los datos o no.
  def __init__(self, imgIDs, labels, batch_size=32, dim=(180, 320), n_channels=3, n_classes=4, shuffle=True):
    self.imgIDs = imgIDs
    self.labels = labels
    self.batch_size = batch_size
    self.dim = dim
    self.n_channels = n_channels
    self.n_classes = n_classes
    self.shuffle = shuffle
    self.on_epoch_end()

  # Retorna el numero de batches del generator.
  def __len__(self):
    return int(np.floor(len(self.imgIDs) / self.batch_size))

  # Retorna un batch.
  def __getitem__(self, index):
    indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
    list_IDs_temp = [self.imgIDs[k] for k in indexes]
    X, y = self.__data_generation(list_IDs_temp)

    return X, y

  # Cuando se termina un epoch, se escogen los siguientes ID.
  def on_epoch_end(self):
    self.indexes = np.arange(len(self.imgIDs))
    if self.shuffle == True:
      np.random.shuffle(self.indexes)

  # Se cargan los datos a medida que se necesitan.
  def __data_generation(self, list_IDs_temp):
    X = np.empty((self.batch_size, *self.dim, self.n_channels))
    y = np.empty((self.batch_size), dtype=int)

    for i, ID in enumerate(list_IDs_temp):
      X[i,] = io.imread("./balanced_dataset_medium/data/" + ID + ".jpg")
      y[i] = self.labels[ID]
    
    X = X.astype("float32") / 255

    return X, to_categorical(y, num_classes=self.n_classes)

# %%
# Observamos los datos del CSV.
dataInfo = pd.read_csv("./balanced_dataset_medium/data_info.csv")
dataInfo
# Out:
#        Unnamed: 0  ...                                            topicID
# 0               0  ...                           ['/m/04rlf', '/m/04rlf']
# 1               1  ...                           ['/m/098wr', '/m/098wr']
# 2               2  ...                           ['/m/04rlf', '/m/064t9']
# 3               3  ...                         ['/m/0bzvm2', '/m/0bzvm2']
# 4               4  ...           ['/m/0bzvm2', '/m/0bzvm2', '/m/0403l3g']
# ...           ...  ...                                                ...
# 19980       19980  ...                           ['/m/04rlf', '/m/01lyv']
# 19981       19981  ...             ['/m/04rlf', '/m/064t9', '/m/0glt670']
# 19982       19982  ...                                       ['/m/04rlf']
# 19983       19983  ...  ['/m/025zzc', '/m/0bzvm2', '/m/0bzvm2', '/m/02...
# 19984       19984  ...               ['/m/02jjt', '/m/02jjt', '/m/02vxn']
#
# [19985 rows x 9 columns]

# %%
# Tamaño de los grupos, donde se indica con proporciones.
# El resto se le asigna al grupo de test.
trainSize = 0.6
valSize = 0.2

# Generamos el diccionario de los labels, y cargamos todos los IDs en una lista.
labels = {}
data = []

for i, row in dataInfo.iterrows():
  data.append(row["ID"])
  labels[row["ID"]] = row["label"]

# Revolvemos la lista de ID.
random.Random(42).shuffle(data)

# Generamos las listas de IDs para cada grupo.
trainData = data[:int(len(data)*trainSize)]
valData = data[int(len(data)*trainSize) : int(len(data)*trainSize) + int(len(data)*valSize)]
testData = data[int(len(data)*trainSize) + int(len(data)*valSize):]

# Creamos el diccionario de listas de ID para cada grupo.
partition = {}
partition["train"] = trainData
partition["validation"] = valData
partition["test"] = testData

# %%
# TODO: Graficar una wea

# %%
# Creamos los generadores.
trainGenerator = DataGenerator(partition["train"], labels)
valGenerator = DataGenerator(partition["validation"], labels)
testGenerator = DataGenerator(partition["test"], labels)

# %%
# Creamos la red y la compilamos.
modelCNN = Sequential()

modelCNN.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(180,320,3)))
modelCNN.add(Dropout(0.20))
modelCNN.add(MaxPooling2D(pool_size=(2, 2)))

modelCNN.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
modelCNN.add(Dropout(0.20))
modelCNN.add(MaxPooling2D(pool_size=(2, 2)))

modelCNN.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
modelCNN.add(Dropout(0.20))
modelCNN.add(MaxPooling2D(pool_size=(2, 2)))

modelCNN.add(Flatten())
modelCNN.add(Dense(32, activation="relu"))
modelCNN.add(Dropout(0.40))

modelCNN.add(Dense(4, activation="softmax"))

modelCNN.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

modelCNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 178, 318, 32)      896
# _________________________________________________________________
# dropout (Dropout)            (None, 178, 318, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 89, 159, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 87, 157, 64)       18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 87, 157, 64)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 78, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 41, 76, 64)        36928
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 41, 76, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 38, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 48640)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                1556512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 1,612,964
# Trainable params: 1,612,964
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Entrenamos la red.
# El steps_per_epoch indica cuantos batches del train son un epoch.
# El validation_steps es lo mismo pero para el validation.
history = modelCNN.fit(trainGenerator, validation_data=valGenerator, use_multiprocessing=True, workers=10, steps_per_epoch=10, validation_steps=10, epochs=10)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 62s 6s/step - loss: 1.6596 - accuracy: 0.2688 - val_loss: 1.3905 - val_accuracy: 0.2188
